# %%
from get_white_house_texts import get_data_whpb
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn
import re
import nltk
import clean_white_house as clean_wh
from nltk.tokenize import word_tokenize, sent_tokenize
import nltk
import pprint
from __future__ import division

pd.set_option('mode.chained_assignment', None)

# %%
briefings = pd.read_csv('briefings-for-cleaning.csv')
remarks = pd.read_csv('remarks-for-cleaning.csv')

# %%
briefings.shape
# Out:
# (251508, 5)

# %%
remarks.shape
# Out:
# (157344, 5)

# %% [markdown]
# # Cleaning

# %%
## takes care of most of the cleaning
# gets rid of rows with the type of document, what time it is, when the end is, etc
remarks = clean_wh.start_table_cleaning(remarks)
briefings = clean_wh.start_table_cleaning(briefings)

# %%
remarks.shape
# Out:
# (146836, 5)

# %%
briefings.shape
# Out:
# (197821, 5)

# %%
remarks = remarks[~remarks.text.str.contains(
    '^(January|February|March|April|May|June|July|August|September|October|November|December)\s\d{1,2}.{1,2}\d{4}'
)]

remarks.reset_index(drop=True, inplace=True)

briefings = briefings[~briefings.text.str.contains(
    '^(January|February|March|April|May|June|July|August|September|October|November|December)\s\d{1,2}.{1,2}\d{4}'
)]

briefings.reset_index(drop=True, inplace=True)
# Out:
# /home/ss1680921/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#
# /home/ss1680921/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.

# %%
remarks.shape
# Out:
# (146767, 5)

# %%
briefings.shape
# Out:
# (197748, 5)

# %%
remarks[remarks.text.str.contains('A.M', regex=False)]
# Out:
# Empty DataFrame
# Columns: [title, date, text, link, doc_id]
# Index: []

# %%
remarks[remarks.text.str.contains('P.M', regex=False)]
# Out:
#                                                 title       date  \
# 98  Remarks by Vice President Pence at a Roundtabl... 2020-12-15
#
#             text                                               link  doc_id
# 98  1:56P.M. EST  https://www.whitehouse.gov/briefings-statement...       4

# %%
briefings[briefings.text.str.contains('A.M', regex=False)]
# Out:
# Empty DataFrame
# Columns: [title, date, text, link, doc_id]
# Index: []

# %%
briefings[briefings.text.str.contains('P.M', regex=False)]
# Out:
#                                                  title       date  \
# 206  Remarks by Vice President Pence at a Roundtabl... 2020-12-15
#
#              text                                               link  doc_id
# 206  1:56P.M. EST  https://www.whitehouse.gov/briefings-statement...      62

# %%
# Those were the exact same rows. I'm going to drop any duplicates by concating 
remarks = remarks[~remarks.text.str.contains('P.M', regex=False)]
briefings = briefings[~briefings.text.str.contains('P.M', regex=False)]

# %%
remarks.text = remarks.text.replace('^Q$', 'PRESS CORPS: ', regex=True)
briefings.text = briefings.text.replace('^Q$', 'PRESS CORPS: ', regex=True)

# %%
remarks['table'] = 'remarks'
briefings['table'] = 'briefings'

# %%
together = pd.concat([remarks, briefings])
## anything that appears in both tables we will keep the remarks copy. 
together.drop_duplicates(subset=['title', 'date'], keep='first', inplace=True)
together = together[together.table == 'briefings']

# %%
print(f'Briefing table shape before dropping duplicates: {briefings.shape}')

briefing_keeps = together.doc_id.tolist()

briefings['doc_keep_bool'] = briefings.doc_id.map(lambda x: True if x in briefing_keeps else False)

briefings = briefings[briefings.doc_keep_bool == True]

briefings.drop(['doc_keep_bool', 'table'], axis=1, inplace=True)
remarks.drop(['table'], axis=1, inplace=True)

print(f'Briefing table shape after dropping duplicates: {briefings.shape}')
# Out:
# Briefing table shape before dropping duplicates: (197747, 6)
# Briefing table shape after dropping duplicates: (49228, 5)

# %%
remarks
# Out:
#                                                     title       date  \
# 0             Remarks by Press Secretary Kayleigh McEnany 2021-01-07
# 1             Remarks by Press Secretary Kayleigh McEnany 2021-01-07
# 2             Remarks by Press Secretary Kayleigh McEnany 2021-01-07
# 3             Remarks by Press Secretary Kayleigh McEnany 2021-01-07
# 4             Remarks by Press Secretary Kayleigh McEnany 2021-01-07
# 5             Remarks by Press Secretary Kayleigh McEnany 2021-01-07
# 6             Remarks by Press Secretary Kayleigh McEnany 2021-01-07
# 7       Remarks by Vice President Pence at the Space F... 2020-12-18
# 8       Remarks by Vice President Pence at the Space F... 2020-12-18
# 9       Remarks by Vice President Pence at the Space F... 2020-12-18
# 10      Remarks by Vice President Pence at the Space F... 2020-12-18
# 11      Remarks by Vice President Pence at the Space F... 2020-12-18
# 12      Remarks by Vice President Pence at the Space F... 2020-12-18
# 13      Remarks by Vice President Pence at the Space F... 2020-12-18
# 14      Remarks by Vice President Pence at the Space F... 2020-12-18
# 15      Remarks by Vice President Pence at the Space F... 2020-12-18
# 16      Remarks by Vice President Pence at the Space F... 2020-12-18
# 17      Remarks by Vice President Pence at the Space F... 2020-12-18
# 18      Remarks by Vice President Pence at the Space F... 2020-12-18
# 19      Remarks by Vice President Pence at the Space F... 2020-12-18
# 20      Remarks by Vice President Pence at the Space F... 2020-12-18
# 21      Remarks by Vice President Pence at the Space F... 2020-12-18
# 22      Remarks by Vice President Pence at the Space F... 2020-12-18
# 23      Remarks by Vice President Pence at the Space F... 2020-12-18
# 24      Remarks by Vice President Pence at the Space F... 2020-12-18
# 25      Remarks by Vice President Pence at the Space F... 2020-12-18
# 26      Remarks by Vice President Pence at the Space F... 2020-12-18
# 27      Remarks by Vice President Pence at the Space F... 2020-12-18
# 28      Remarks by Vice President Pence at the Space F... 2020-12-18
# 29      Remarks by Vice President Pence at the Space F... 2020-12-18
# ...                                                   ...        ...
# 146737                              The Inaugural Address 2017-01-20
# 146738                              The Inaugural Address 2017-01-20
# 146739                              The Inaugural Address 2017-01-20
# 146740                              The Inaugural Address 2017-01-20
# 146741                              The Inaugural Address 2017-01-20
# 146742                              The Inaugural Address 2017-01-20
# 146743                              The Inaugural Address 2017-01-20
# 146744                              The Inaugural Address 2017-01-20
# 146745                              The Inaugural Address 2017-01-20
# 146746                              The Inaugural Address 2017-01-20
# 146747                              The Inaugural Address 2017-01-20
# 146748                              The Inaugural Address 2017-01-20
# 146749                              The Inaugural Address 2017-01-20
# 146750                              The Inaugural Address 2017-01-20
# 146751                              The Inaugural Address 2017-01-20
# 146752                              The Inaugural Address 2017-01-20
# 146753                              The Inaugural Address 2017-01-20
# 146754                              The Inaugural Address 2017-01-20
# 146755                              The Inaugural Address 2017-01-20
# 146756                              The Inaugural Address 2017-01-20
# 146757                              The Inaugural Address 2017-01-20
# 146758                              The Inaugural Address 2017-01-20
# 146759                              The Inaugural Address 2017-01-20
# 146760                              The Inaugural Address 2017-01-20
# 146761                              The Inaugural Address 2017-01-20
# 146762                              The Inaugural Address 2017-01-20
# 146763                              The Inaugural Address 2017-01-20
# 146764                              The Inaugural Address 2017-01-20
# 146765                              The Inaugural Address 2017-01-20
# 146766                              The Inaugural Address 2017-01-20
#
#                                                      text  \
# 0                      James S. Brady Press Briefing Room
# 1       MS. MCENANY: I am here to deliver this message...
# 2       I stood here at this podium the day after a hi...
# 3       We grieve for the loss of life and those injur...
# 4       What we saw yesterday was a group of violent r...
# 5       Those who are working in this building are wor...
# 6                                    Thank you very much.
# 7       THE VICE PRESIDENT: Well, thank you all for be...
# 8       Many kind things have been said about your Vic...
# 9       We just left the Oval Office with the Presiden...
# 10      But we’re grateful to the contributions of all...
# 11      And there are members of Congress who are with...
# 12      And the first person ever to mention to me tha...
# 13      And I want to give particular note to a member...
# 14      I also want to take a moment to express my app...
# 15      And it’s my greatest honor to be here with so ...
# 16      There are several people to thank, but I — the...
# 17      But to all the members of our Armed Forces wit...
# 18      You know, yesterday marked the birthday of fli...
# 19      But in just a few short days, on Sunday, Decem...
# 20      That historic moment was a culmination of an e...
# 21      It would be in June of 2018, the President fir...
# 22      And since that historic moment, the United Sta...
# 23      After the Space Force became law, the Presiden...
# 24      He chose a man who — you’ve heard from these p...
# 25      So join me in thanking General Jay Raymond, hi...
# 26      It’s amazing to think that this spring General...
# 27      In April, those two men were literally the ent...
# 28      In fact, General Raymond tells us that we anti...
# 29      You know, heroes like him and like all of you ...
# ...                                                   ...
# 146737  We will follow two simple rules: Buy American ...
# 146738  We will seek friendship and goodwill with the ...
# 146739  We do not seek to impose our way of life on an...
# 146740  We will reinforce old alliances and form new o...
# 146741  At the bedrock of our politics will be a total...
# 146742  When you open your heart to patriotism, there ...
# 146743  The Bible tells us, “how good and pleasant it ...
# 146744  We must speak our minds openly, debate our dis...
# 146745  When America is united, America is totally uns...
# 146746  There should be no fear – we are protected, an...
# 146747  We will be protected by the great men and wome...
# 146748  Finally, we must think big and dream even bigger.
# 146749  In America, we understand that a nation is onl...
# 146750  We will no longer accept politicians who are a...
# 146751                   The time for empty talk is over.
# 146752                    Now arrives the hour of action.
# 146753  Do not let anyone tell you it cannot be done. ...
# 146754  We will not fail. Our country will thrive and ...
# 146755  We stand at the birth of a new millennium, rea...
# 146756  A new national pride will stir our souls, lift...
# 146757  It is time to remember that old wisdom our sol...
# 146758  And whether a child is born in the urban spraw...
# 146759  So to all Americans, in every city near and fa...
# 146760                   You will never be ignored again.
# 146761  Your voice, your hopes, and your dreams, will ...
# 146762       Together, We Will Make America Strong Again.
# 146763                We Will Make America Wealthy Again.
# 146764                  We Will Make America Proud Again.
# 146765                   We Will Make America Safe Again.
# 146766  And, Yes, Together, We Will Make America Great...
#
#                                                      link  doc_id
# 0       https://www.whitehouse.gov/briefings-statement...       0
# 1       https://www.whitehouse.gov/briefings-statement...       0
# 2       https://www.whitehouse.gov/briefings-statement...       0
# 3       https://www.whitehouse.gov/briefings-statement...       0
# 4       https://www.whitehouse.gov/briefings-statement...       0
# 5       https://www.whitehouse.gov/briefings-statement...       0
# 6       https://www.whitehouse.gov/briefings-statement...       0
# 7       https://www.whitehouse.gov/briefings-statement...       1
# 8       https://www.whitehouse.gov/briefings-statement...       1
# 9       https://www.whitehouse.gov/briefings-statement...       1
# 10      https://www.whitehouse.gov/briefings-statement...       1
# 11      https://www.whitehouse.gov/briefings-statement...       1
# 12      https://www.whitehouse.gov/briefings-statement...       1
# 13      https://www.whitehouse.gov/briefings-statement...       1
# 14      https://www.whitehouse.gov/briefings-statement...       1
# 15      https://www.whitehouse.gov/briefings-statement...       1
# 16      https://www.whitehouse.gov/briefings-statement...       1
# 17      https://www.whitehouse.gov/briefings-statement...       1
# 18      https://www.whitehouse.gov/briefings-statement...       1
# 19      https://www.whitehouse.gov/briefings-statement...       1
# 20      https://www.whitehouse.gov/briefings-statement...       1
# 21      https://www.whitehouse.gov/briefings-statement...       1
# 22      https://www.whitehouse.gov/briefings-statement...       1
# 23      https://www.whitehouse.gov/briefings-statement...       1
# 24      https://www.whitehouse.gov/briefings-statement...       1
# 25      https://www.whitehouse.gov/briefings-statement...       1
# 26      https://www.whitehouse.gov/briefings-statement...       1
# 27      https://www.whitehouse.gov/briefings-statement...       1
# 28      https://www.whitehouse.gov/briefings-statement...       1
# 29      https://www.whitehouse.gov/briefings-statement...       1
# ...                                                   ...     ...
# 146737  https://www.whitehouse.gov/briefings-statement...    1977
# 146738  https://www.whitehouse.gov/briefings-statement...    1977
# 146739  https://www.whitehouse.gov/briefings-statement...    1977
# 146740  https://www.whitehouse.gov/briefings-statement...    1977
# 146741  https://www.whitehouse.gov/briefings-statement...    1977
# 146742  https://www.whitehouse.gov/briefings-statement...    1977
# 146743  https://www.whitehouse.gov/briefings-statement...    1977
# 146744  https://www.whitehouse.gov/briefings-statement...    1977
# 146745  https://www.whitehouse.gov/briefings-statement...    1977
# 146746  https://www.whitehouse.gov/briefings-statement...    1977
# 146747  https://www.whitehouse.gov/briefings-statement...    1977
# 146748  https://www.whitehouse.gov/briefings-statement...    1977
# 146749  https://www.whitehouse.gov/briefings-statement...    1977
# 146750  https://www.whitehouse.gov/briefings-statement...    1977
# 146751  https://www.whitehouse.gov/briefings-statement...    1977
# 146752  https://www.whitehouse.gov/briefings-statement...    1977
# 146753  https://www.whitehouse.gov/briefings-statement...    1977
# 146754  https://www.whitehouse.gov/briefings-statement...    1977
# 146755  https://www.whitehouse.gov/briefings-statement...    1977
# 146756  https://www.whitehouse.gov/briefings-statement...    1977
# 146757  https://www.whitehouse.gov/briefings-statement...    1977
# 146758  https://www.whitehouse.gov/briefings-statement...    1977
# 146759  https://www.whitehouse.gov/briefings-statement...    1977
# 146760  https://www.whitehouse.gov/briefings-statement...    1977
# 146761  https://www.whitehouse.gov/briefings-statement...    1977
# 146762  https://www.whitehouse.gov/briefings-statement...    1977
# 146763  https://www.whitehouse.gov/briefings-statement...    1977
# 146764  https://www.whitehouse.gov/briefings-statement...    1977
# 146765  https://www.whitehouse.gov/briefings-statement...    1977
# 146766  https://www.whitehouse.gov/briefings-statement...    1977
#
# [146766 rows x 5 columns]

# %%
remarks['total_words'] = remarks.text.map(lambda x: len(x.split(' ')))
remarks['first_letter_up'] = remarks.text.map(lambda x: [i[0].isupper() for i in x.split(' ')])
remarks['cap_first_by_total'] = remarks['first_letter_up'] / remarks['total_words']

# %%
delete_lines = remarks.groupby('doc_id', as_index=False).first().apply(
    lambda x: x['text'] if len(x['text'].split(':')) == 1 else np.nan, axis=1).dropna().tolist()

# %%
len(set(delete_lines))
# Out:
# 1

# %%
second_line = remarks.groupby('doc_id', as_index=False).nth(1)
third_line = remarks.groupby('doc_id', as_index=False).nth(2)

# %%
delete_lines += second_line[(second_line.cap_first_by_total == 1) & 
                                (~second_line.text.str.contains(':')) ].text.unique().tolist()

# %%
len(set(delete_lines))
# Out:
# 1

# %%
delete_lines += third_line[(third_line.total_words < 15) & 
           (~third_line.text.str.contains(':')) & 
           (third_line.cap_first_by_total > .5)].text.tolist()

# %%
len(set(delete_lines))
# Out:
# 1

# %%
remarks['delete_bool'] = remarks.text.map(lambda x: True if x in delete_lines else False)
# doing the same for briefings while I'm at it
briefings['delete_bool'] = briefings.text.map(lambda x: True if x in delete_lines else False)

remarks = remarks[remarks.delete_bool == False]
briefings = briefings[briefings.delete_bool == False]

remarks.drop(['delete_bool'], axis=1, inplace=True)
briefings.drop(['delete_bool'], axis=1, inplace=True)

remarks.reset_index(drop=True, inplace=True)
briefings.reset_index(drop=True, inplace=True)

# %%
remarks.shape
# Out:
# (76, 8)

# %%
remarks[remarks.title.str.contains('Statement')]
# Out:
# Empty DataFrame
# Columns: [title, date, text, link, doc_id, first_letter_up, total_words, cap_first_by_total]
# Index: []

# %%
first_line = remarks.groupby('doc_id', as_index=False).first()

# %%
delete_lines = first_line[(~first_line.text.str.contains(':')) & 
                          (first_line.total_words < 45) &
                          (first_line.cap_first_by_total > .3) & 
                          (~first_line.text.str.contains('hello'))].text.tolist()

remarks['delete_bool'] = remarks.text.map(lambda x: True if x in delete_lines else False)
# doing the same for briefings while I'm at it
briefings['delete_bool'] = briefings.text.map(lambda x: True if x in delete_lines else False)

remarks = remarks[remarks.delete_bool == False]
briefings = briefings[briefings.delete_bool == False]

remarks.drop(['delete_bool'], axis=1, inplace=True)
briefings.drop(['delete_bool'], axis=1, inplace=True)

remarks.reset_index(drop=True, inplace=True)
briefings.reset_index(drop=True, inplace=True)

# %%
print(remarks.shape)
print(briefings.shape)
# Out:
# (75, 8)
# (195117, 5)

# %%
remarks.to_csv('clean-remarks-1-14.csv', index=False)
briefings.to_csv('clean-briefings-1-14.csv', index=False)

# %%
remarks = pd.read_csv('clean-remarks-1-14.csv')
briefings = pd.read_csv('clean-briefings-1-14.csv')

# %%
print(remarks.shape)
print(briefings.shape)
# Out:
# (144623, 8)
# (48898, 5)

# %%
remarks = remarks[~remarks.title.str.contains('Message from')]
briefings = briefings[~briefings.title.str.contains('Message from')]

remarks.reset_index(drop=True, inplace=True)
briefings.reset_index(drop=True, inplace=True)

# %%
remarks[remarks.text.str.contains('\)')]
# Out:
#                                                     title        date  \
# 49916   Remarks by Vice President Pence and Prime Mini...  2020-01-23
# 113953  Remarks by President Trump at Swearing-In Cere...  2018-05-21
# 129829  Remarks by President Trump at Meeting with Hou...  2017-11-02
#
#                                         text  \
# 49916              The flags are presented.)
# 113953  The Oath of Office is administered.)
# 129829       President is given a document.)
#
#                                                      link  doc_id  \
# 49916   https://www.whitehouse.gov/briefings-statement...     410
# 113953  https://www.whitehouse.gov/briefings-statement...    1313
# 129829  https://www.whitehouse.gov/briefings-statement...    1610
#
#         first_letter_up  total_words  cap_first_by_total
# 49916                 1            4                0.25
# 113953                3            6                0.50
# 129829                1            5                0.20

# %%
remarks = remarks[~remarks.text.str.contains('\)')]
remarks.reset_index(drop=True, inplace=True)

# %%
briefings[briefings.text.str.contains('\)')]
# Out:
#                                                    title        date  \
# 42200  Daily Press Briefing by Press Secretary Sean S...  2017-03-28
#
#                                                     text  \
# 42200  A few things I want to highlight. Last night, ...
#
#                                                     link  doc_id
# 42200  https://www.whitehouse.gov/briefings-statement...    6350

# %%
briefings.iloc[42200, 2]
# Out:
# 'A few things I want to highlight. Last night, the President announced his intent to nominate Makan Delrahim to serve as Assistant Attorney General of the Anti-Trust Divisio) at the Department of Justice.'

# %%
briefings.iloc[42200, 2] = briefings.iloc[42200, 2].replace(')', 'n')

# %%
remarks[remarks.text.str.contains('(January|February|March|April|May|June|July|August|September|October|November|December)\s\d{1,2},? \d{4}')]
# Out:
# /home/ss1680921/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.
#                                                     title        date  \
# 2017    Remarks by President Trump to Guests at the Al...  2020-10-01
# 2738    Remarks by President Trump Honoring Bay of Pig...  2020-09-23
# 3998    Remarks by President Trump at Presentation of ...  2020-09-11
# 7709    Remarks by Vice President Pence at a Support L...  2020-08-14
# 15072   Remarks by Vice President Pence at a Naturaliz...  2020-07-02
# 15758   The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15759   The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15760   The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15761   The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15762   The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15763   The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15765   The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15766   The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15767   The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15768   The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15769   The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15770   The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15771   The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15772   The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15773   The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15774   The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15775   The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 16876   Remarks by Vice President Pence at a Roundtabl...  2020-06-20
# 17287   Remarks by President Trump at Announcement of ...  2020-06-17
# 24159   Remarks by President Trump in Roundtable Discu...  2020-05-05
# 24165   Remarks by President Trump in Roundtable Discu...  2020-05-05
# 39907   Remarks by President Trump, Vice President Pen...  2020-03-20
# 43046   Remarks by President Trump at the Presentation...  2020-03-10
# 49923   Remarks by Vice President Pence at the Fifth W...  2020-01-23
# 56319   Remarks by President Trump at the New York Cit...  2019-11-11
# ...                                                   ...         ...
# 105968  Remarks by President Trump at the Presentation...  2018-08-22
# 106936  Remarks by Vice President Pence at Honorable C...  2018-08-01
# 109675  Remarks by President Trump Announcing Judge Br...  2018-07-09
# 109701  Remarks by Vice President Pence at U.S. Immigr...  2018-07-06
# 110413  Remarks by President Trump at the Presentation...  2018-06-26
# 112689  Remarks by President Trump at Signing of the V...  2018-06-06
# 113299  Remarks by President Trump at the Presentation...  2018-05-24
# 116932  Remarks by President Trump at the Tax Cuts for...  2018-04-16
# 118666  Remarks by President Trump at Greek Independen...  2018-03-22
# 119363  Remarks by LTG H.R. McMaster at the United Sta...  2018-03-15
# 119393  Remarks by LTG H.R. McMaster at the United Sta...  2018-03-15
# 120348  Remarks by the First Lady at the White House O...  2018-03-01
# 120368  Remarks by Vice President Pence at the Departm...  2018-03-01
# 124644  President Donald J. Trump’s State of the Union...  2018-01-30
# 125230  Remarks by LTG H.R. McMaster at the United Sta...  2018-01-21
# 125246  Remarks by LTG H.R. McMaster at the United Sta...  2018-01-21
# 125625  Remarks by President Trump at Signing of Procl...  2018-01-12
# 125630  Remarks by President Trump at Signing of Procl...  2018-01-12
# 126630  Remarks to the Troops by Vice President Pence ...  2017-12-21
# 126843  Remarks by President Trump on the Administrati...  2017-12-18
# 127836  Remarks by the Vice President Commemorating U....  2017-11-28
# 127841  Remarks by the Vice President Commemorating U....  2017-11-28
# 127888  Remarks by President Trump at an Event Honorin...  2017-11-27
# 130504  Remarks by President Trump at Presentation of ...  2017-10-23
# 131508  Remarks by President Trump Announcing the Nomi...  2017-10-12
# 131564  Remarks by Vice President Mike Pence at Nation...  2017-10-11
# 135479  Remarks by President Trump at Presentation of ...  2017-07-31
# 139123  Remarks by Vice President Pence at Cinco de Ma...  2017-05-04
# 141940  Remarks by the Vice President to the Latino Co...  2017-03-10
# 142774  Remarks by the Vice President and European Cou...  2017-02-20
#
#                                                      text  \
# 2017    Few institutions in history have done more for...
# 2738    On April 17, 1961, the 1,400 Cuban exiles of B...
# 3998    MILITARY AIDE: Attention to orders. The Medal ...
# 7709    I must tell you, the world saw the character o...
# 15072   You see, he came to this country — stepped off...
# 15758   [1] John Garnaut, “Engineers of the Soul: Ideo...
# 15759   [2] John Garnaut, “Engineers of the Soul: Ideo...
# 15760   [3] John Garnaut, “Engineers of the Soul: Ideo...
# 15761   [4] “Document 9: A ChinaFile Translation,” Nov...
# 15762   [5] “Document 9: A ChinaFile Translation,” Nov...
# 15763   [6] Bradford Betz, “China has arrested hundred...
# 15765   [8] White House, “United States Strategic Appr...
# 15766   [9] White House, “Executive Order on Securing ...
# 15767   [10] Department of Commerce, “Commerce Address...
# 15768   [11] Department of State, “Designation of Addi...
# 15769   [12] White House, “United States Strategic App...
# 15770   [13] U.S. Customs and Border Patrol, “CBP Issu...
# 15771   [14] White House, “President Donald J. Trump i...
# 15772   [15] White House, “Remarks by President Trump ...
# 15773   [16] White House, “Proclamation on the Suspens...
# 15774   [17] Blake Burman, “Trump orders federal retir...
# 15775   [18] White House, “Remarks by President Trump ...
# 16876   But I think what you said, Pastor AJ, and what...
# 17287   On March 23, 2003, in one horrific day, 18 Mar...
# 24159   SECOND LADY LIZER: You know, it seems to be a ...
# 24165   We got to Tamicka Platero who is from Little —...
# 39907   And one thing, as a New Yorker myself — for th...
# 43046   Jack was named a Vice Chief of Staff of the Ar...
# 49923   When soldiers opened the gates of Auschwitz on...
# 56319   During World War Two, 63 million tons of suppl...
# ...                                                   ...
# 105968  Technical Sergeant John A. Chapman distinguish...
# 106936  On June 25, 1950, at dawn, communist North Kor...
# 109675  My wife Ashley is a West Texan. A graduate of ...
# 109701  Abolishing ICE also would give terrorists a ne...
# 110413  First Lieutenant Garlin M. Conner distinguishe...
# 112689  Today we also mark another milestone, the 74th...
# 113299  In the early morning of March 4, 2002, Senior ...
# 116932  DR. JUNQUERA: Good afternoon, Mr. President. M...
# 118666  Today, we commemorate the Greek struggle for i...
# 119363  Eventually convicted of treason, she was sente...
# 119393  Following Assad’s April 4, 2017, sarin attack ...
# 120348  On September 22, 2017, a needle took the life ...
# 120368  Just over one year after the terrorist attacks...
# 124644                 THE WHITE HOUSE, January 30, 2018.
# 125230  As prepared for delivery by LTG H.R. McMaster ...
# 125246  Training under challenging and realistic condi...
# 125625  Today, we gather in the White House to honor t...
# 125630  I will now sign the proclamation making Januar...
# 126630  And never doubt that your mission — your missi...
# 126843  When the American people speak, all of us shou...
# 127836  And on November 29, 1947 — 70 years ago tomorr...
# 127841  It happened when on May 14, 1948, Israel decla...
# 127888  On August 7, 1942 — 75 years ago — 1st Marine ...
# 130504  On September 11, 1970, Mike was called on his ...
# 131508  It’s an incredible privilege to work at the Wh...
# 131564  Richard Michael Cawley, who stepped off onto E...
# 135479  On May 13, 1969, less than three months after ...
# 139123  And she said, “you have to go to America” beca...
# 141940  Richard Michael Cawley actually stepped ashore...
# 142774  On Saturday in Munich, you mentioned that duri...
#
#                                                      link  doc_id  \
# 2017    https://www.whitehouse.gov/briefings-statement...      39
# 2738    https://www.whitehouse.gov/briefings-statement...      51
# 3998    https://www.whitehouse.gov/briefings-statement...      71
# 7709    https://www.whitehouse.gov/briefings-statement...     108
# 15072   https://www.whitehouse.gov/briefings-statement...     180
# 15758   https://www.whitehouse.gov/briefings-statement...     189
# 15759   https://www.whitehouse.gov/briefings-statement...     189
# 15760   https://www.whitehouse.gov/briefings-statement...     189
# 15761   https://www.whitehouse.gov/briefings-statement...     189
# 15762   https://www.whitehouse.gov/briefings-statement...     189
# 15763   https://www.whitehouse.gov/briefings-statement...     189
# 15765   https://www.whitehouse.gov/briefings-statement...     189
# 15766   https://www.whitehouse.gov/briefings-statement...     189
# 15767   https://www.whitehouse.gov/briefings-statement...     189
# 15768   https://www.whitehouse.gov/briefings-statement...     189
# 15769   https://www.whitehouse.gov/briefings-statement...     189
# 15770   https://www.whitehouse.gov/briefings-statement...     189
# 15771   https://www.whitehouse.gov/briefings-statement...     189
# 15772   https://www.whitehouse.gov/briefings-statement...     189
# 15773   https://www.whitehouse.gov/briefings-statement...     189
# 15774   https://www.whitehouse.gov/briefings-statement...     189
# 15775   https://www.whitehouse.gov/briefings-statement...     189
# 16876   https://www.whitehouse.gov/briefings-statement...     201
# 17287   https://www.whitehouse.gov/briefings-statement...     206
# 24159   https://www.whitehouse.gov/briefings-statement...     263
# 24165   https://www.whitehouse.gov/briefings-statement...     263
# 39907   https://www.whitehouse.gov/briefings-statement...     323
# 43046   https://www.whitehouse.gov/briefings-statement...     336
# 49923   https://www.whitehouse.gov/briefings-statement...     411
# 56319   https://www.whitehouse.gov/briefings-statement...     490
# ...                                                   ...     ...
# 105968  https://www.whitehouse.gov/briefings-statement...    1195
# 106936  https://www.whitehouse.gov/briefings-statement...    1210
# 109675  https://www.whitehouse.gov/briefings-statement...    1244
# 109701  https://www.whitehouse.gov/briefings-statement...    1245
# 110413  https://www.whitehouse.gov/briefings-statement...    1257
# 112689  https://www.whitehouse.gov/briefings-statement...    1291
# 113299  https://www.whitehouse.gov/briefings-statement...    1305
# 116932  https://www.whitehouse.gov/briefings-statement...    1376
# 118666  https://www.whitehouse.gov/briefings-statement...    1402
# 119363  https://www.whitehouse.gov/briefings-statement...    1414
# 119393  https://www.whitehouse.gov/briefings-statement...    1414
# 120348  https://www.whitehouse.gov/briefings-statement...    1432
# 120368  https://www.whitehouse.gov/briefings-statement...    1433
# 124644  https://www.whitehouse.gov/briefings-statement...    1483
# 125230  https://www.whitehouse.gov/briefings-statement...    1499
# 125246  https://www.whitehouse.gov/briefings-statement...    1499
# 125625  https://www.whitehouse.gov/briefings-statement...    1514
# 125630  https://www.whitehouse.gov/briefings-statement...    1514
# 126630  https://www.whitehouse.gov/briefings-statement...    1530
# 126843  https://www.whitehouse.gov/briefings-statement...    1533
# 127836  https://www.whitehouse.gov/briefings-statement...    1561
# 127841  https://www.whitehouse.gov/briefings-statement...    1561
# 127888  https://www.whitehouse.gov/briefings-statement...    1562
# 130504  https://www.whitehouse.gov/briefings-statement...    1621
# 131508  https://www.whitehouse.gov/briefings-statement...    1638
# 131564  https://www.whitehouse.gov/briefings-statement...    1639
# 135479  https://www.whitehouse.gov/briefings-statement...    1737
# 139123  https://www.whitehouse.gov/briefings-statement...    1839
# 141940  https://www.whitehouse.gov/briefings-statement...    1918
# 142774  https://www.whitehouse.gov/briefings-statement...    1942
#
#         first_letter_up  total_words  cap_first_by_total
# 2017                 13           86            0.151163
# 2738                 13           61            0.213115
# 3998                 16           43            0.372093
# 7709                 10          112            0.089286
# 15072                13           74            0.175676
# 15758                 8           16            0.500000
# 15759                 8           16            0.500000
# 15760                 8           16            0.500000
# 15761                 4           10            0.400000
# 15762                 4           10            0.400000
# 15763                 3           18            0.166667
# 15765                 9           17            0.529412
# 15766                25           46            0.543478
# 15767                15           24            0.625000
# 15768                 9           17            0.529412
# 15769                27           48            0.562500
# 15770                16           33            0.484848
# 15771                11           20            0.550000
# 15772                 8           15            0.533333
# 15773                12           26            0.461538
# 15774                 4           19            0.210526
# 15775                 8           15            0.533333
# 16876                11           62            0.177419
# 17287                10           49            0.204082
# 24159                14           76            0.184211
# 24165                 9           24            0.375000
# 39907                22           71            0.309859
# 43046                10           57            0.175439
# 49923                 5           54            0.092593
# 56319                10           58            0.172414
# ...                 ...          ...                 ...
# 105968               20           38            0.526316
# 106936               10           38            0.263158
# 109675               31          131            0.236641
# 109701                8           78            0.102564
# 110413               21           63            0.333333
# 112689                8           68            0.117647
# 113299               10           69            0.144928
# 116932               16           36            0.444444
# 118666                5           36            0.138889
# 119363                5           31            0.161290
# 119393                9           34            0.264706
# 120348                8           65            0.123077
# 120368               17           60            0.283333
# 124644                4            6            0.666667
# 125230                9           18            0.500000
# 125246               17           49            0.346939
# 125625               18           46            0.391304
# 125630               11           51            0.215686
# 126630               14           99            0.141414
# 126843                8           55            0.145455
# 127836                8           32            0.250000
# 127841                4           32            0.125000
# 127888               24           99            0.242424
# 130504                6           34            0.176471
# 131508               10           53            0.188679
# 131564               14           31            0.451613
# 135479               10           76            0.131579
# 139123               20          108            0.185185
# 141940               20           66            0.303030
# 142774               20          100            0.200000
#
# [95 rows x 8 columns]

# %%
remarks[remarks.doc_id == 189]
# Out:
#                                                    title        date  \
# 15705  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15706  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15707  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15708  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15709  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15710  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15711  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15712  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15713  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15714  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15715  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15716  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15717  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15718  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15719  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15720  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15721  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15722  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15723  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15724  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15725  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15726  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15727  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15728  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15729  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15730  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15731  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15732  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15733  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15734  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# ...                                                  ...         ...
# 15746  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15747  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15748  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15749  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15750  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15751  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15752  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15753  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15754  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15755  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15756  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15757  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15758  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15759  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15760  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15761  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15762  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15763  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15764  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15765  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15766  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15767  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15768  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15769  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15770  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15771  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15772  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15773  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15774  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
# 15775  The Chinese Communist Party’s Ideology and Glo...  2020-06-26
#
#                                                     text  \
# 15705  Well, thank you Governor. That was an extraord...
# 15706  It is wonderful to be here at the Arizona Comm...
# 15707  I bring you greetings from the 45th President ...
# 15708  I appreciate the kind invitation to come discu...
# 15709  America, under President Trump’s leadership, h...
# 15710  It was under this premise that we welcomed Chi...
# 15711  As China grew richer and stronger, we believed...
# 15712  We could not have been more wrong—and this mis...
# 15713  The answer is simple: because we did not pay h...
# 15714  Let us be clear, the Chinese Communist Party i...
# 15715  Under communism, individuals are merely a mean...
# 15716  These ideas sound remote and outdated to us. T...
# 15717  The Chinese Communist Party seeks total contro...
# 15718  “In Classical Chinese statecraft,” Garnaut has...
# 15719  Propaganda plays a central political role for ...
# 15720  So within China, this approach means mandatory...
# 15721  And indeed, just recently, between January 1 a...
# 15722  The Chinese Communist Party reinterprets relig...
# 15723  Americans should be concerned. We should not b...
# 15724  Over the past decade, the Party has invested b...
# 15725  Recently, Chinese propaganda persuaded so many...
# 15726  On TikTok, a Chinese-owned social media platfo...
# 15727  Last week, Twitter announced the suspension of...
# 15728  In March, the CCP expelled American journalist...
# 15729  In addition to influencing what information Am...
# 15730  When the general manager of the Houston Rocket...
# 15731  Under pressure from the CCP, Marriott, and Ame...
# 15732  Beijing has used its financial might and marke...
# 15733  The CCP is seeking leverage over individual Am...
# 15734  The CCP accomplishes this goal, in part, by su...
# ...                                                  ...
# 15746  Fourth, President Trump left the United Nation...
# 15747  Fifth, President Trump limited the People’s Li...
# 15748  Sixth, the President moved to halt the investm...
# 15749  This week, the Defense Department is submittin...
# 15750  Now, these steps are just the start as America...
# 15751  President Trump understands that lasting peace...
# 15752  Together with our allies and partners, we will...
# 15753  We will stay true to our principles—especially...
# 15754  As I close, let me be clear – we have deep res...
# 15755  To the Chinese Communist Party, I say, as the ...
# 15756  As Americans, I am certain that we will rise t...
# 15757  Again, thank you for joining me here today. It...
# 15758  [1] John Garnaut, “Engineers of the Soul: Ideo...
# 15759  [2] John Garnaut, “Engineers of the Soul: Ideo...
# 15760  [3] John Garnaut, “Engineers of the Soul: Ideo...
# 15761  [4] “Document 9: A ChinaFile Translation,” Nov...
# 15762  [5] “Document 9: A ChinaFile Translation,” Nov...
# 15763  [6] Bradford Betz, “China has arrested hundred...
# 15764  [7] Hoover Institution, 2018, “Chinese Influen...
# 15765  [8] White House, “United States Strategic Appr...
# 15766  [9] White House, “Executive Order on Securing ...
# 15767  [10] Department of Commerce, “Commerce Address...
# 15768  [11] Department of State, “Designation of Addi...
# 15769  [12] White House, “United States Strategic App...
# 15770  [13] U.S. Customs and Border Patrol, “CBP Issu...
# 15771  [14] White House, “President Donald J. Trump i...
# 15772  [15] White House, “Remarks by President Trump ...
# 15773  [16] White House, “Proclamation on the Suspens...
# 15774  [17] Blake Burman, “Trump orders federal retir...
# 15775  [18] White House, “Remarks by President Trump ...
#
#                                                     link  doc_id  \
# 15705  https://www.whitehouse.gov/briefings-statement...     189
# 15706  https://www.whitehouse.gov/briefings-statement...     189
# 15707  https://www.whitehouse.gov/briefings-statement...     189
# 15708  https://www.whitehouse.gov/briefings-statement...     189
# 15709  https://www.whitehouse.gov/briefings-statement...     189
# 15710  https://www.whitehouse.gov/briefings-statement...     189
# 15711  https://www.whitehouse.gov/briefings-statement...     189
# 15712  https://www.whitehouse.gov/briefings-statement...     189
# 15713  https://www.whitehouse.gov/briefings-statement...     189
# 15714  https://www.whitehouse.gov/briefings-statement...     189
# 15715  https://www.whitehouse.gov/briefings-statement...     189
# 15716  https://www.whitehouse.gov/briefings-statement...     189
# 15717  https://www.whitehouse.gov/briefings-statement...     189
# 15718  https://www.whitehouse.gov/briefings-statement...     189
# 15719  https://www.whitehouse.gov/briefings-statement...     189
# 15720  https://www.whitehouse.gov/briefings-statement...     189
# 15721  https://www.whitehouse.gov/briefings-statement...     189
# 15722  https://www.whitehouse.gov/briefings-statement...     189
# 15723  https://www.whitehouse.gov/briefings-statement...     189
# 15724  https://www.whitehouse.gov/briefings-statement...     189
# 15725  https://www.whitehouse.gov/briefings-statement...     189
# 15726  https://www.whitehouse.gov/briefings-statement...     189
# 15727  https://www.whitehouse.gov/briefings-statement...     189
# 15728  https://www.whitehouse.gov/briefings-statement...     189
# 15729  https://www.whitehouse.gov/briefings-statement...     189
# 15730  https://www.whitehouse.gov/briefings-statement...     189
# 15731  https://www.whitehouse.gov/briefings-statement...     189
# 15732  https://www.whitehouse.gov/briefings-statement...     189
# 15733  https://www.whitehouse.gov/briefings-statement...     189
# 15734  https://www.whitehouse.gov/briefings-statement...     189
# ...                                                  ...     ...
# 15746  https://www.whitehouse.gov/briefings-statement...     189
# 15747  https://www.whitehouse.gov/briefings-statement...     189
# 15748  https://www.whitehouse.gov/briefings-statement...     189
# 15749  https://www.whitehouse.gov/briefings-statement...     189
# 15750  https://www.whitehouse.gov/briefings-statement...     189
# 15751  https://www.whitehouse.gov/briefings-statement...     189
# 15752  https://www.whitehouse.gov/briefings-statement...     189
# 15753  https://www.whitehouse.gov/briefings-statement...     189
# 15754  https://www.whitehouse.gov/briefings-statement...     189
# 15755  https://www.whitehouse.gov/briefings-statement...     189
# 15756  https://www.whitehouse.gov/briefings-statement...     189
# 15757  https://www.whitehouse.gov/briefings-statement...     189
# 15758  https://www.whitehouse.gov/briefings-statement...     189
# 15759  https://www.whitehouse.gov/briefings-statement...     189
# 15760  https://www.whitehouse.gov/briefings-statement...     189
# 15761  https://www.whitehouse.gov/briefings-statement...     189
# 15762  https://www.whitehouse.gov/briefings-statement...     189
# 15763  https://www.whitehouse.gov/briefings-statement...     189
# 15764  https://www.whitehouse.gov/briefings-statement...     189
# 15765  https://www.whitehouse.gov/briefings-statement...     189
# 15766  https://www.whitehouse.gov/briefings-statement...     189
# 15767  https://www.whitehouse.gov/briefings-statement...     189
# 15768  https://www.whitehouse.gov/briefings-statement...     189
# 15769  https://www.whitehouse.gov/briefings-statement...     189
# 15770  https://www.whitehouse.gov/briefings-statement...     189
# 15771  https://www.whitehouse.gov/briefings-statement...     189
# 15772  https://www.whitehouse.gov/briefings-statement...     189
# 15773  https://www.whitehouse.gov/briefings-statement...     189
# 15774  https://www.whitehouse.gov/briefings-statement...     189
# 15775  https://www.whitehouse.gov/briefings-statement...     189
#
#        first_letter_up  total_words  cap_first_by_total
# 15705               27          195            0.138462
# 15706               21          110            0.190909
# 15707               16           64            0.250000
# 15708               22           88            0.250000
# 15709               14          100            0.140000
# 15710               12           50            0.240000
# 15711               10           53            0.188679
# 15712                7           40            0.175000
# 15713                6           54            0.111111
# 15714               30          101            0.297030
# 15715                5           54            0.092593
# 15716               14           73            0.191781
# 15717                5           31            0.161290
# 15718               11           77            0.142857
# 15719                9           79            0.113924
# 15720               14           79            0.177215
# 15721                6           41            0.146341
# 15722               14           90            0.155556
# 15723               13           67            0.194030
# 15724               13           87            0.149425
# 15725                8           51            0.156863
# 15726                5           30            0.166667
# 15727               15           73            0.205479
# 15728               14           33            0.424242
# 15729               15           50            0.300000
# 15730                9           51            0.176471
# 15731               12           37            0.324324
# 15732               15           73            0.205479
# 15733                5           43            0.116279
# 15734               13           97            0.134021
# ...                ...          ...                 ...
# 15746               20           81            0.246914
# 15747                7           33            0.212121
# 15748                8           48            0.166667
# 15749               10           38            0.263158
# 15750                6           53            0.113208
# 15751               18           68            0.264706
# 15752                9           43            0.209302
# 15753                8           69            0.115942
# 15754               12           43            0.279070
# 15755               10           47            0.212766
# 15756               12           57            0.210526
# 15757               10           31            0.322581
# 15758                8           16            0.500000
# 15759                8           16            0.500000
# 15760                8           16            0.500000
# 15761                4           10            0.400000
# 15762                4           10            0.400000
# 15763                3           18            0.166667
# 15764                8           13            0.615385
# 15765                9           17            0.529412
# 15766               25           46            0.543478
# 15767               15           24            0.625000
# 15768                9           17            0.529412
# 15769               27           48            0.562500
# 15770               16           33            0.484848
# 15771               11           20            0.550000
# 15772                8           15            0.533333
# 15773               12           26            0.461538
# 15774                4           19            0.210526
# 15775                8           15            0.533333
#
# [71 rows x 8 columns]

# %%
remarks = remarks[~remarks.text.str.contains('^\[.+\]')]
remarks.reset_index(drop=True, inplace=True)

# %%
briefings[briefings.text.str.contains('^\[.+\]')]
# Out:
# Empty DataFrame
# Columns: [title, date, text, link, doc_id]
# Index: []

# %%
remarks = remarks[remarks.text != '.']
remarks.reset_index(drop=True, inplace=True)

# %%
last_line = remarks.groupby('doc_id', as_index=False).last()

# %%
last_line[(~last_line.text.str.contains('[Tt]hank')) &
          (~last_line.text.str.contains('[:?]')) &  
          (~last_line.text.str.contains('So')) & 
          (~last_line.text.str.contains('God')) & 
          (~last_line.text.str.contains('you')) & 
          (~last_line.text.str.contains('[Gg]oodbye'))]
# Out:
#       doc_id                                              title        date  \
# 35        35  Remarks by President Trump Before Marine One D...  2020-10-15
# 63        63  Remarks by President Trump Before Marine One D...  2020-09-15
# 69        69  Remarks by President Trump in a Ceremony Recog...  2020-09-14
# 71        71  Remarks by President Trump at Presentation of ...  2020-09-11
# 144      144  Remarks by President Trump at the Presentation...  2020-07-24
# 161      161  Remarks by Vice President Pence During a Round...  2020-07-14
# 173      173  Remarks by President Trump and President López...  2020-07-08
# 248      248  Remarks by President Trump at Presidential Rec...  2020-05-15
# 319      319  Remarks by Vice President Pence in a Press Gaggle  2020-03-23
# 353      353  Remarks by President Trump After Marine One Ar...  2020-03-03
# 362      362  Remarks by President Trump, Vice President Pen...  2020-02-29
# 411      411  Remarks by Vice President Pence at the Fifth W...  2020-01-23
# 415      415  Remarks by President Trump at a Dinner with Gl...  2020-01-21
# 435      435  Remarks by President Trump at Signing Ceremony...  2019-12-20
# 496      496  Remarks by President Trump Welcoming the 2019 ...  2019-11-04
# 502      502  Remarks by President Trump at Presentation of ...  2019-10-30
# 648      648  Remarks by President Trump Before Marine One D...  2019-08-24
# 652      652  Remarks by Vice President Pence in Press Gaggl...  2019-08-21
# 669      669  Remarks by President Trump in Press Gaggle Abo...  2019-08-08
# 670      670  Remarks by President Trump Before Meeting with...  2019-08-07
# 720      720  Remarks by Vice President Pence in a Press Gaggle  2019-07-10
# 728      728  Remarks by President Trump Before Marine One D...  2019-07-05
# 759      759  Remarks by President Trump at Presentation of ...  2019-06-25
# 798      798  Remarks by Vice President Pence and Prime Mini...  2019-05-30
# 816      816    Remarks by Vice President Pence in Press Gaggle  2019-05-22
# 823      823  Remarks by Vice President Pence at Taylor Univ...  2019-05-18
# 865      866  Remarks by Vice President Pence in Press Gaggl...  2019-04-24
# 904      905  Remarks by President Trump Before Marine One D...  2019-03-28
# 906      907  Remarks by President Trump at Presentation of ...  2019-03-27
# 938      939  Remarks by President Trump Before Marine One D...  2019-03-08
# 948      949  Remarks by President Trump Welcoming the 2018 ...  2019-03-04
# 1110    1112  Remarks by President Trump at the Presentation...  2018-10-17
# 1143    1145  Remarks by President Trump at the Presentation...  2018-10-02
# 1149    1151  Remarks by President Trump at the United Natio...  2018-09-26
# 1206    1208  Remarks by CEA Chairman Kevin Hassett to the J...  2018-08-03
# 1240    1242  Remarks by Vice President Pence Before Meeting...  2018-07-10
# 1255    1257  Remarks by President Trump at the Presentation...  2018-06-26
# 1273    1275         Remarks by President Trump in Press Gaggle  2018-06-15
# 1303    1305  Remarks by President Trump at the Presentation...  2018-05-24
# 1357    1359  Remarks by President Trump and President Macro...  2018-04-25
# 1358    1360  Remarks by Vice President Pence and President ...  2018-04-24
# 1468    1470  Remarks by Vice President Pence and Prime Mini...  2018-02-07
# 1471    1473               Press Gaggle by Vice President Pence  2018-02-06
# 1481    1483  President Donald J. Trump’s State of the Union...  2018-01-30
# 1496    1499  Remarks by LTG H.R. McMaster at the United Sta...  2018-01-21
# 1499    1502  Remarks by Vice President Mike Pence to Member...  2018-01-20
# 1538    1541  Remarks by President Trump at Signing of H.R. ...  2017-12-12
# 1543    1546  Remarks by the President at a Hanukkah Celebra...  2017-12-07
# 1561    1564  Remarks by President Trump to Members of the C...  2017-11-23
# 1585    1588  Remarks by President Trump in Meet-and-Greet w...  2017-11-10
# 1597    1600  Remarks by President Trump and President Moon ...  2017-11-07
# 1618    1621  Remarks by President Trump at Presentation of ...  2017-10-23
# 1633    1636  Remarks by the Vice President at Signing of Ex...  2017-10-12
# 1722    1726  Remarks by Vice President Pence and President ...  2017-08-13
# 1769    1773  Remarks by the President Signing an Executive ...  2017-06-30
# 1800    1805  Remarks by President Trump in Welcoming the 20...  2017-06-12
# 1837    1842  Remarks by President Trump on Healthcare Vote ...  2017-05-04
# 1921    1926  Excerpts from President Donald J. Trump’s Addr...  2017-02-28
#
#                                                    text  \
# 35       But we won — we won a big case — $7.5 billion.
# 63    The governor of Nevada should not be in charge...
# 69    The brave actions and superior airmanship of t...
# 71    Sergeant First Class Payne’s gallantry under f...
# 144   Following his success on the track, Mr. Ryun c...
# 161   With that, I’d be happy to recognize the Secre...
# 173   Long live the friendship of our two nations. L...
# 248                                       Okay, please.
# 319   President Trump and I absolutely believe, for ...
# 353           He gave a very bad signal, in my opinion.
# 362   And we will continue to have aggressive public...
# 411   Oseh shalom bimromav. Hu ya’aseh shalom aleinu...
# 415   Maybe not well known, but we are probably the ...
# 435                                    It’s now signed.
# 496        Congratulations, everybody. Congratulations.
# 502   Sergeant Williams’s actions are in keeping wit...
# 648   We have to make sure that our taxpayer — look,...
# 652   We really believe that’s a great story to tell...
# 669   And I’m very impressed with his family. I’m ve...
# 670   We’re going to go in and see some very brave p...
# 720   A nation without borders is not a nation. And ...
# 728                                                  ED
# 759   Acting on instinct to save the members of his ...
# 798   We recognize we’re in a context where the glob...
# 816   There’s simply no question that the USMCA is a...
# 823         Congratulations, Class of 2019. You did it.
# 865   And now it’s time for the rest of Washington t...
# 904   I think that case is an absolute embarrassment...
# 906   Staff Sergeant Atkins’s undaunted courage, war...
# 938                               I’m going to Alabama.
# 948                               Folks, go and eat up.
# 1110  By his undaunted courage, selfless sacrifice, ...
# 1143  Staff Sergeant Shurer’s actions are in keeping...
# 1149  I now resume my function as president of the S...
# 1206  Kevin Hassett is the Chairman of the Council o...
# 1240  And we’re honored to be able to bring him here...
# 1255  His actions are in keeping with the highest tr...
# 1273  But just to put it — one more time, President ...
# 1303  Throughout the next 14 hours, Senior Chief Sla...
# 1357  And, in turn, please allow me to raise my glas...
# 1358                                    Santé. Cheers.
# 1468  And so tonight I offer a toast to the U.S.-Jap...
# 1471  The most recent report should give every Ameri...
# 1481                 THE WHITE HOUSE, January 30, 2018.
# 1496                                        Works Cited
# 1499  And I hope that my message here, with Presiden...
# 1538  I won’t be showing all of this to everybody, b...
# 1543  I’d like to invite Louise to say a few words. ...
# 1561  Let’s go, fellas, come on. Let’s get up here. ...
# 1585                                         very much.
# 1597  Today, President Trump visited Pyeongtaek mili...
# 1618  Sergeant Rose’s extraordinary heroism and self...
# 1633  with that, ladies and gentlemen, it’s my privi...
# 1722  And in the aftermath of yesterday’s violence, ...
# 1769                                              Okay.
# 1800               Jim, come on up and say a few words.
# 1837  And, Paul Ryan, come up and say a few words. C...
# 1921  From now on, America will be empowered by our ...
#
#                                                    link  first_letter_up  \
# 35    https://www.whitehouse.gov/briefings-statement...                1
# 63    https://www.whitehouse.gov/briefings-statement...                7
# 69    https://www.whitehouse.gov/briefings-statement...               16
# 71    https://www.whitehouse.gov/briefings-statement...               12
# 144   https://www.whitehouse.gov/briefings-statement...                9
# 161   https://www.whitehouse.gov/briefings-statement...                6
# 173   https://www.whitehouse.gov/briefings-statement...               15
# 248   https://www.whitehouse.gov/briefings-statement...                1
# 319   https://www.whitehouse.gov/briefings-statement...               11
# 353   https://www.whitehouse.gov/briefings-statement...                1
# 362   https://www.whitehouse.gov/briefings-statement...                1
# 411   https://www.whitehouse.gov/briefings-statement...                6
# 415   https://www.whitehouse.gov/briefings-statement...                3
# 435   https://www.whitehouse.gov/briefings-statement...                1
# 496   https://www.whitehouse.gov/briefings-statement...                2
# 502   https://www.whitehouse.gov/briefings-statement...               15
# 648   https://www.whitehouse.gov/briefings-statement...                9
# 652   https://www.whitehouse.gov/briefings-statement...                3
# 669   https://www.whitehouse.gov/briefings-statement...                7
# 670   https://www.whitehouse.gov/briefings-statement...                5
# 720   https://www.whitehouse.gov/briefings-statement...                6
# 728   https://www.whitehouse.gov/briefings-statement...                1
# 759   https://www.whitehouse.gov/briefings-statement...               10
# 798   https://www.whitehouse.gov/briefings-statement...                4
# 816   https://www.whitehouse.gov/briefings-statement...                9
# 823   https://www.whitehouse.gov/briefings-statement...                3
# 865   https://www.whitehouse.gov/briefings-statement...               10
# 904   https://www.whitehouse.gov/briefings-statement...                1
# 906   https://www.whitehouse.gov/briefings-statement...                9
# 938   https://www.whitehouse.gov/briefings-statement...                2
# 948   https://www.whitehouse.gov/briefings-statement...                1
# 1110  https://www.whitehouse.gov/briefings-statement...               10
# 1143  https://www.whitehouse.gov/briefings-statement...               16
# 1149  https://www.whitehouse.gov/briefings-statement...                5
# 1206  https://www.whitehouse.gov/briefings-statement...                6
# 1240  https://www.whitehouse.gov/briefings-statement...                7
# 1255  https://www.whitehouse.gov/briefings-statement...                6
# 1273  https://www.whitehouse.gov/briefings-statement...                5
# 1303  https://www.whitehouse.gov/briefings-statement...               12
# 1357  https://www.whitehouse.gov/briefings-statement...                8
# 1358  https://www.whitehouse.gov/briefings-statement...                2
# 1468  https://www.whitehouse.gov/briefings-statement...                5
# 1471  https://www.whitehouse.gov/briefings-statement...                6
# 1481  https://www.whitehouse.gov/briefings-statement...                4
# 1496  https://www.whitehouse.gov/briefings-statement...                2
# 1499  https://www.whitehouse.gov/briefings-statement...               12
# 1538  https://www.whitehouse.gov/briefings-statement...                3
# 1543  https://www.whitehouse.gov/briefings-statement...                3
# 1561  https://www.whitehouse.gov/briefings-statement...                3
# 1585  https://www.whitehouse.gov/briefings-statement...                0
# 1597  https://www.whitehouse.gov/briefings-statement...               16
# 1618  https://www.whitehouse.gov/briefings-statement...                8
# 1633  https://www.whitehouse.gov/briefings-statement...                4
# 1722  https://www.whitehouse.gov/briefings-statement...                9
# 1769  https://www.whitehouse.gov/briefings-statement...                1
# 1800  https://www.whitehouse.gov/briefings-statement...                1
# 1837  https://www.whitehouse.gov/briefings-statement...                4
# 1921  https://www.whitehouse.gov/briefings-statement...                2
#
#       total_words  cap_first_by_total
# 35             12            0.083333
# 63             71            0.098592
# 69             69            0.231884
# 71             37            0.324324
# 144            50            0.180000
# 161            21            0.285714
# 173            30            0.500000
# 248             2            0.500000
# 319            53            0.207547
# 353             9            0.111111
# 362            33            0.030303
# 411            12            0.500000
# 415            23            0.130435
# 435             3            0.333333
# 496             3            0.666667
# 502            33            0.454545
# 648            45            0.200000
# 652            33            0.090909
# 669            48            0.145833
# 670            26            0.192308
# 720            60            0.100000
# 728             1            1.000000
# 759            67            0.149254
# 798            89            0.044944
# 816            37            0.243243
# 823             7            0.428571
# 865            84            0.119048
# 904            25            0.040000
# 906            38            0.236842
# 938             4            0.500000
# 948             5            0.200000
# 1110           34            0.294118
# 1143           35            0.457143
# 1149           20            0.250000
# 1206           11            0.545455
# 1240           42            0.166667
# 1255           27            0.222222
# 1273           19            0.263158
# 1303           57            0.210526
# 1357           75            0.106667
# 1358            2            1.000000
# 1468           45            0.111111
# 1471           74            0.081081
# 1481            6            0.666667
# 1496            2            1.000000
# 1499           63            0.190476
# 1538           24            0.125000
# 1543           11            0.272727
# 1561           13            0.230769
# 1585            2            0.000000
# 1597           95            0.168421
# 1618           51            0.156863
# 1633           18            0.222222
# 1722           81            0.111111
# 1769            1            1.000000
# 1800            9            0.111111
# 1837           16            0.250000
# 1921           16            0.125000

# %%
remarks = remarks[~remarks.text.str.contains('WHITE HOUSE')]

# %%
remarks = remarks[~remarks.text.str.contains('Cited')]

# %%
remarks[remarks.doc_id == 1499].iloc[-1]
# Out:
# title                 Remarks by LTG H.R. McMaster at the United Sta...
# date                                                         2018-01-21
# text                  I commend all of you for choosing service to o...
# link                  https://www.whitehouse.gov/briefings-statement...
# doc_id                                                             1499
# first_letter_up                                                       4
# total_words                                                          34
# cap_first_by_total                                             0.117647
# Name: 125234, dtype: object

# %%
remarks[remarks.title.str.contains('State of the Union')].doc_id.unique()
# Out:
# array([ 393,  988,  990, 1482, 1483])

# %%
remarks[remarks.title.str.contains('State of the Union')].groupby('doc_id').first()
# Out:
#                                                     title        date  \
# doc_id
# 393     Remarks by President Trump in State of the Uni...  2020-02-04
# 988     Remarks by President Trump in State of the Uni...  2019-02-06
# 990     President Donald J. Trump’s State of the Union...  2019-02-05
# 1482    Remarks by President Trump in State of the Uni...  2018-01-30
# 1483    President Donald J. Trump’s State of the Union...  2018-01-30
#
#                                                      text  \
# doc_id
# 393     THE PRESIDENT: Thank you very much. Thank you....
# 988     THE PRESIDENT: Madam Speaker, Mr. Vice Preside...
# 990                 TO THE CONGRESS OF THE UNITED STATES:
# 1482    THE PRESIDENT: Mr. Speaker, Mr. Vice President...
# 1483                TO THE CONGRESS OF THE UNITED STATES:
#
#                                                      link  first_letter_up  \
# doc_id
# 393     https://www.whitehouse.gov/briefings-statement...                5
# 988     https://www.whitehouse.gov/briefings-statement...               14
# 990     https://www.whitehouse.gov/briefings-statement...                7
# 1482    https://www.whitehouse.gov/briefings-statement...               14
# 1483    https://www.whitehouse.gov/briefings-statement...                7
#
#         total_words  cap_first_by_total
# doc_id
# 393              12            0.416667
# 988              23            0.608696
# 990               7            1.000000
# 1482             21            0.666667
# 1483              7            1.000000

# %%
remarks = remarks[~remarks.title.str.contains("President Donald J. Trump’s State of the Union")]
remarks.reset_index(drop=True, inplace=True)

# %%
remarks = remarks[~remarks.text.str.contains("As prepared")]
remarks.reset_index(drop=True, inplace=True)

# %%
## these documents don't begin with a speaker that I can use to make a transcript style table so they are going to 
## be deleted
remarks.groupby('doc_id', as_index=False).first().apply(
    lambda x: (x['doc_id'], x['text']) if len(x['text'].split(':')) == 1 else np.nan, axis=1).dropna()
# Out:
# 7       (7, And before I begin, allow me to bring gree...
# 30      (30, I’d like to thank Dean Godson and Policy ...
# 151     (151, As we see rising coronavirus cases not j...
# 154     (154, You know, in our first three years, Pres...
# 162     (162, I remember the early conversations with ...
# 189     (189, Well, thank you Governor. That was an ex...
# 220     (220, So we look forward to being there. Some ...
# 222     (222, I think that, before I leave, I want to ...
# 223     (223, Before going further on this exciting da...
# 267     (267, Good morning everyone. I’m Matt Pottinge...
# 470     (470, Thank you for the kind introduction. I a...
# 471     (471, Well, thank you Mort for that very kind ...
# 944     (945, Earlier today, Mrs. Trump participated i...
# 1032    (1034, Well, Kim, thanks very much, and thanks...
# 1081    (1084, Thank you, Ingeborg, for your kind intr...
# 1093    (1096, I’ve been following very closely the ev...
# 1205    (1208, Good morning. I’m pleased to be here to...
# 1330    (1333, Thank you for the lovely introduction C...
# 1336                             (1339, Well, hello NRA!)
# 1364    (1367, It is a pleasure to be here in New York...
# 1387    (1390, Thank you General Jim Jones. And thank ...
# 1411    (1414, Thank you Cameron. It is an honor to be...
# 1431    (1434, Thank you, Bud, for that nice introduct...
# 1445    (1448, Thank you Wolfgang. You and your entire...
# 1494    (1499, Thank you, Tayler for that introduction...
# 1537    (1542, Thank you, Dean. I want to congratulate...
# 1551    (1556, Thank you, John, for that kind introduc...
# 1620    (1625, I want to thank FDD for the work it’s d...
# 1779    (1785, Thank you for that kind introduction. I...
# 1846    (1853, Thank you, Chris, for that kind introdu...
# 1898    (1905, This week, I traveled to Nashville, Ten...
# 1919    (1926, Each American generation passes the tor...
# 1966    (1973, Well, good afternoon, everyone. Thank y...
# dtype: object

# %%
remarks.head()
# Out:
#                                          title        date  \
# 0  Remarks by Press Secretary Kayleigh McEnany  2021-01-07
# 1  Remarks by Press Secretary Kayleigh McEnany  2021-01-07
# 2  Remarks by Press Secretary Kayleigh McEnany  2021-01-07
# 3  Remarks by Press Secretary Kayleigh McEnany  2021-01-07
# 4  Remarks by Press Secretary Kayleigh McEnany  2021-01-07
#
#                                                 text  \
# 0  MS. MCENANY: I am here to deliver this message...
# 1  I stood here at this podium the day after a hi...
# 2  We grieve for the loss of life and those injur...
# 3  What we saw yesterday was a group of violent r...
# 4  Those who are working in this building are wor...
#
#                                                 link  doc_id  first_letter_up  \
# 0  https://www.whitehouse.gov/briefings-statement...       0               12
# 1  https://www.whitehouse.gov/briefings-statement...       0               10
# 2  https://www.whitehouse.gov/briefings-statement...       0                3
# 3  https://www.whitehouse.gov/briefings-statement...       0                6
# 4  https://www.whitehouse.gov/briefings-statement...       0                6
#
#    total_words  cap_first_by_total
# 0           72            0.166667
# 1           66            0.151515
# 2           37            0.081081
# 3           69            0.086957
# 4           42            0.142857

# %%
doc_ids_delete = remarks.groupby('doc_id', as_index=False).first().apply(
    lambda x: x['doc_id'] if len(x['text'].split(':')) == 1 else np.nan, axis=1).dropna().tolist()

remarks['delete_docs'] = remarks.doc_id.map(lambda x: True if x in doc_ids_delete else False)

remarks = remarks[remarks.delete_docs == False]

remarks.drop(['first_letter_up', 'total_words', 'cap_first_by_total', 'delete_docs'], axis=1, inplace=True)

remarks.reset_index(drop=True, inplace=True)

# %%
remarks.shape
# Out:
# (143044, 5)

# %%
## starting to clean the rest of briefings
briefings['total_words'] = briefings.text.map(lambda x: len(x.split(' ')))
briefings['first_letter_up'] = briefings.text.map(lambda x: sum([i[0].isupper() if len(i) > 0 else 0 for i in x.split(' ')]))
briefings['cap_first_by_total'] = briefings['first_letter_up'] / briefings['total_words']

# %%
min(briefings.first_letter_up)
# Out:
# 0

# %%
first_line = briefings.groupby('doc_id', as_index=False).first()

# %%
# these are docs that don't have a speaker at the start of the first line so they are going to be deleted
first_line[(~first_line.text.str.contains(':')) & (first_line.cap_first_by_total < .75)]
# Out:
#      doc_id                                              title        date  \
# 3       123  Press Briefing by Vice President Pence and Mem...  2020-11-19
# 29      678  Remarks by President Trump on the Jobs Numbers...  2020-07-02
# 285    6201  On-the-Record Press Call on the Education Fede...  2017-04-26
# 349    6622           Statement by Press Secretary Sean Spicer  2017-01-31
#
#                                                   text  \
# 3    I’m joined today, and you’ll hear in a few mom...
# 29   I’d like to just announce the spectacular news...
# 285  Hi, this is Rob Goad. I’m a senior Department ...
# 349  Good afternoon. I know you’re all looking forw...
#
#                                                   link  total_words  \
# 3    https://www.whitehouse.gov/briefings-statement...           72
# 29   https://www.whitehouse.gov/briefings-statement...           53
# 285  https://www.whitehouse.gov/briefings-statement...           32
# 349  https://www.whitehouse.gov/briefings-statement...           44
#
#      first_letter_up  cap_first_by_total
# 3                 15            0.208333
# 29                 8            0.150943
# 285                9            0.281250
# 349                9            0.204545

# %%
# and all the locations and lines below can be deleted as well
first_line[(~first_line.text.str.contains(':')) & (first_line.cap_first_by_total > .75)].text.unique()
# Out:
# array(['James S. Brady Press Briefing Room February 26, 2020',
#        'Aboard Air Force One En Route Washington, D.C.',
#        'Aboard Air Force One En Route Fargo, North Dakota',
#        'Aboard Air Force One En Route Tampa, Florida',
#        'En Route Dubuque, Iowa',
#        'Aboard Air Force One En Route Lewisburg, West Virginia',
#        'JW Marriott Singapore',
#        'Aboard Air Force One En Route Dallas, Texas',
#        'Aboard Air Force One En Route Nashville, Tennessee',
#        'Aboard Air Force One En Route South Bend, Indiana',
#        'Hilton West Palm Beach',
#        'Aboard Air Force One En Route Cleveland, Ohio',
#        'Aboard Air Force One En Route St. Louis, Missouri',
#        'Aboard Air Force One En Route Cincinnati, Ohio',
#        'En Route Pittsburgh, Pennsylvania',
#        'En Route Nashville, Tennessee', 'En Route Pensacola, Florida',
#        'Aboard Air Force One En Route Da Nang, Vietnam',
#        'China World Hotel Beijing, China', 'En Route Beijing, China',
#        'New York Hilton Midtown – Rhinelander Gallery South New York, New York',
#        'Hilton Midtown New York, New York',
#        'Southwest Florida International Airport Fort Myers, Florida',
#        'Aboard Air Force One En Route Fort Myers, Florida',
#        'Aboard Air Force One En Route Bismarck, North Dakota',
#        'PRESS BRIEFING BY PRESS SECRETARY SARAH SANDERS, TREASURY SECRETARY STEVEN MNUCHIN, NATIONAL SECURITY ADVISER GENERAL H.R. MCMASTER AND HOMELAND SECURITY ADVISER TOM BOSSERT',
#        'PRESS GAGGLE BY PRESS SECRETARY SARAH SANDERS, ACTING ICE DIRECTOR TOM HOMAN, AND A SENIOR ADMINISTRATION OFFICIAL',
#        'Aboard Air Force One En Route Huntington, West Virginia',
#        'Aboard Air Force One En Route Ronkonkoma, New York',
#        'Aboard Air Force One En Route Beaver, West Virginia',
#        'Aboard Air Force One En Route Newark, New Jersey',
#        'Aboard Air Force One En Route Cedar Rapids, Iowa',
#        'Via Conference Call',
#        'Aboard Air Force One En Route Atlanta, Georgia',
#        'PRESS BRIEFING BY RAY STARLING, SPECIAL ASSISTANT TO THE PRESIDENT FOR AGRICULTURE, TRADE AND FOOD ASSISTANCE, ON EXECUTIVE ORDER PROMOTING AGRICULTURE AND RURAL PROSPERITY',
#        'Aboard Air Force One En Route Kenosha, Wisconsin',
#        'PRESS BRIEFING BY OMB DIRECTOR MICK MULVANEY ON A COMPREHENSIVE PLAN FOR REFORMING THE FEDERAL GOVERNMENT AND REDUCING THE FEDERAL CIVILIAN WORKFORCE',
#        'James Brady S. Briefing Room', 'James S. Brady Briefing Room',
#        'Tideline Ocean Resort and Spa',
#        'Tideline Resort and Spa Palm Beach, Florida',
#        'En Route West Palm Beach, Florida', 'En Route Palm Beach, Florida',
#        'Tideline Ocean Resort & Spa Palm Beach, Florida',
#        'Aboard Air Force One En Route Orlando, Florida',
#        'En Route Joint Base Andrews', 'West Wing',
#        'Hilton-West Palm Beach West Palm Beach, Florida',
#        'En Route Melbourne, Florida'], dtype=object)

# %%
print(f'Table shape before dropping rows: {briefings.shape}')

docs_delete = first_line[(~first_line.text.str.contains(':')) & 
                         (first_line.cap_first_by_total < .75)].doc_id.tolist()

lines_delete = first_line[(~first_line.text.str.contains(':')) & 
                         (first_line.cap_first_by_total > .75)].text.tolist()

briefings['doc_delete'] = briefings.doc_id.map(lambda x: True if x in docs_delete else False)
briefings['row_delete'] = briefings.text.map(lambda x: True if x in lines_delete else False)

briefings = briefings[briefings.doc_delete == False]
briefings = briefings[briefings['row_delete'] == False]

briefings.drop(['doc_delete', 'row_delete', 'total_words', 'first_letter_up', 'cap_first_by_total'], 
               axis=1, inplace=True)


briefings.reset_index(drop=True, inplace=True)

print(f'Table shape after dropping rows: {briefings.shape}')
# Out:
# Table shape before dropping rows: (48898, 10)
# Table shape after dropping rows: (48330, 8)

# %%
first_line = briefings.groupby('doc_id', as_index=False).first()

# %%
first_line[~first_line.text.str.contains(':')]
# Out:
#      doc_id                                              title        date  \
# 231    5652  Press Gaggle by Press Secretary Sarah Sanders ...  2017-08-22
#
#                                             text  \
# 231  Aboard Air Force One En Route Yuma, Arizona
#
#                                                   link  total_words  \
# 231  https://www.whitehouse.gov/briefings-statement...            8
#
#      first_letter_up  cap_first_by_total
# 231                8                 1.0

# %%
briefings = briefings[~briefings.text.str.contains('En Route')]

briefings.reset_index(drop=True, inplace=True)

# %%
# Hopefully the last time checking this
first_line = briefings.groupby('doc_id', as_index=False).first()
first_line[~first_line.text.str.contains(':')]
# Out:
# Empty DataFrame
# Columns: [doc_id, title, date, text, link, total_words, first_letter_up, cap_first_by_total]
# Index: []

# %%
last_line = briefings.groupby('doc_id', as_index=False).last()

# %%
# The last lines look all good as well so our remarks and briefings are cleaned up now.
last_line[(~last_line.text.str.contains(':')) & (~last_line.text.str.contains('[Tt]hank'))]
# Out:
#      doc_id                                              title        date  \
# 0        60  Press Briefing by Press Secretary Kayleigh McE...  2020-12-16
# 4       267  Press Briefing by Press Secretary Kayleigh McE...  2020-10-01
# 5       302  Press Briefing by Press Secretary Kayleigh McE...  2020-09-24
# 22      592  Press Briefing by Press Secretary Kayleigh McE...  2020-07-21
# 30      690  Press Briefing by Press Secretary Kayleigh McE...  2020-06-29
# 39      825  Press Briefing by Press Secretary Kayleigh McE...  2020-05-23
# 46      949  Remarks by President Trump, Vice President Pen...  2020-04-20
# 52     1164  Press Briefing by Vice President Pence and Mem...  2020-03-06
# 56     1270  Press Briefing by Acting OMB Director Russ Vought  2020-02-10
# 152    4659  Remarks by Vice President Pence in Press Gaggl...  2018-02-08
# 162    4801  Press Gaggle by Principal Deputy Press Secreta...  2018-01-18
# 175    4950  Background Conference Call on the Vice Preside...  2017-12-15
# 176    4956  Press Briefing by Office of Information and Re...  2017-12-14
# 183    5025  Press Gaggle by Deputy Press Secretary Hogan G...  2017-12-04
# 184    5034  Press Briefing by Press Secretary Sarah Sander...  2017-11-30
# 199    5273  Press Briefing by Press Secretary Sarah Sander...  2017-10-19
# 214    5498  Press Briefing by Press Secretary Sarah Sander...  2017-09-15
# 224    5571    Press Briefing by Press Secretary Sarah Sanders  2017-09-05
# 293    6262  Background Press Call on the Vice President’s ...  2017-04-14
# 305    6310     Press Briefing on the Congressional Review Act  2017-04-05
#
#                                                   text  \
# 0    Really interesting turn of events and good for...
# 4    Ideas do no target police officers. Ideas do n...
# 5    Our police officers deserve our respect, and t...
# 22   And Dr. Birx, for weeks, has been sending out ...
# 30   It is inexcusable, the failed Russia reporting...
# 39   It’s a long weekend. You guys have three days ...
# 46   So it’s a very good question. I appreciate it....
# 52   So although your numbers are correct, it isn’t...
# 56   We’re going to keep proposing these types of b...
# 152  The backdrop of his discussions with North Kor...
# 162                                  All right, folks.
# 175  And so I think that you’ve seen they’ve have b...
# 176  And so having this enormous accumulation of re...
# 183  And lastly, I’d like to address Jerusalem. Tha...
# 184  And I’m going to go get some water and a few c...
# 199          And I do appreciate your time. Take care.
# 214  As you can hear, the President is getting read...
# 224                          Hope you have a good day.
# 293  So I wouldn’t anticipate anything other than —...
# 305  And actually, before we all go, I want one oth...
#
#                                                   link  total_words  \
# 0    https://www.whitehouse.gov/briefings-statement...           21
# 4    https://www.whitehouse.gov/briefings-statement...           38
# 5    https://www.whitehouse.gov/briefings-statement...           59
# 22   https://www.whitehouse.gov/briefings-statement...           74
# 30   https://www.whitehouse.gov/briefings-statement...           31
# 39   https://www.whitehouse.gov/briefings-statement...           43
# 46   https://www.whitehouse.gov/briefings-statement...           17
# 52   https://www.whitehouse.gov/briefings-statement...           15
# 56   https://www.whitehouse.gov/briefings-statement...           34
# 152  https://www.whitehouse.gov/briefings-statement...           67
# 162  https://www.whitehouse.gov/briefings-statement...            3
# 175  https://www.whitehouse.gov/briefings-statement...           43
# 176  https://www.whitehouse.gov/briefings-statement...           24
# 183  https://www.whitehouse.gov/briefings-statement...           65
# 184  https://www.whitehouse.gov/briefings-statement...           39
# 199  https://www.whitehouse.gov/briefings-statement...            8
# 214  https://www.whitehouse.gov/briefings-statement...           28
# 224  https://www.whitehouse.gov/briefings-statement...            6
# 293  https://www.whitehouse.gov/briefings-statement...           15
# 305  https://www.whitehouse.gov/briefings-statement...           71
#
#      first_letter_up  cap_first_by_total
# 0                  2            0.095238
# 4                  9            0.236842
# 5                  5            0.084746
# 22                 9            0.121622
# 30                13            0.419355
# 39                 8            0.186047
# 46                 4            0.235294
# 52                 2            0.133333
# 56                 2            0.058824
# 152               12            0.179104
# 162                1            0.333333
# 175                5            0.116279
# 176                2            0.083333
# 183                7            0.107692
# 184                4            0.102564
# 199                3            0.375000
# 214                6            0.214286
# 224                1            0.166667
# 293                2            0.133333
# 305                5            0.070423

# %%
remarks = pd.read_csv('remarks-pickup.csv')
briefings = pd.read_csv('briefings-pickup.csv')

# %%
remarks.date = pd.to_datetime(remarks.date)
briefings.date = pd.to_datetime(briefings.date)

# %% [markdown]
# # Making transcript style table

# %%
new_remarks = clean_wh.create_transcript_table(remarks)
new_briefings = clean_wh.create_transcript_table(briefings)

# %%
remarks_first = new_remarks.groupby('doc_id', as_index=False).first()
briefings_first = new_briefings.groupby('doc_id', as_index=False).first()

# %%
remarks_first[remarks_first.speaker.isnull()]
# Out:
#       doc_id                                              title       date  \
# 169      174  Statement from the Press Secretary Regarding S... 2020-07-08
# 174      179  Remarks by Vice President in Briefing with Gov... 2020-07-02
# 719      731  Remarks by White House Senior Advisor Jared Ku... 2019-07-04
# 1051    1067  Remarks by Vice President Pence at the 2018 AP... 2018-11-16
# 1200    1220  Remarks by Vice President Pence at Ministerial... 2018-07-26
# 1793    1829  Remarks by the Vice President at Grove City Co... 2017-05-20
# 1935    1975  President Trump and Prime Minister May’s Openi... 2017-01-27
# 1937    1977                              The Inaugural Address 2017-01-20
#
#                                                    link speaker  \
# 169   https://www.whitehouse.gov/briefings-statement...     NaN
# 174   https://www.whitehouse.gov/briefings-statement...     NaN
# 719   https://www.whitehouse.gov/briefings-statement...     NaN
# 1051  https://www.whitehouse.gov/briefings-statement...     NaN
# 1200  https://www.whitehouse.gov/briefings-statement...     NaN
# 1793  https://www.whitehouse.gov/briefings-statement...     NaN
# 1935  https://www.whitehouse.gov/briefings-statement...     NaN
# 1937  https://www.whitehouse.gov/briefings-statement...     NaN
#
#                                                    text  \
# 169   Since Day One, the Trump Administration has so...
# 174   Governor, the President wanted me to be here t...
# 719   Thank you, very much. And thank you to everyon...
# 1051  Thank you, Scott. And thank you all for that w...
# 1200  Thank you, Secretary Pompeo. To the Secretary,...
# 1793  Grove City College Grove City, Pennsylvania TH...
# 1935  President Donald J. Trump: “Thank you very muc...
# 1937  Chief Justice Roberts, President Carter, Presi...
#
#                                           original_text
# 169   Since Day One, the Trump Administration has so...
# 174   Governor, the President wanted me to be here t...
# 719   Thank you, very much. And thank you to everyon...
# 1051  Thank you, Scott. And thank you all for that w...
# 1200  Thank you, Secretary Pompeo. To the Secretary,...
# 1793  Grove City College Grove City, Pennsylvania TH...
# 1935  President Donald J. Trump: “Thank you very muc...
# 1937  Chief Justice Roberts, President Carter, Presi...

# %%
briefings_first[briefings_first.speaker.isnull()]
# Out:
# Empty DataFrame
# Columns: [doc_id, title, date, link, total_words, first_letter_up, cap_first_by_total, speaker, text, original_text]
# Index: []

# %%
drop_docs = remarks_first[remarks_first.speaker.isnull()].doc_id.tolist()

new_remarks['drop_docs'] = new_remarks.doc_id.map(lambda x: True if x in drop_docs else False)

new_remarks = new_remarks[new_remarks.drop_docs == False]

new_remarks.drop(['drop_docs'], axis=1, inplace=True)

new_remarks.reset_index(drop=True, inplace=True)

# %%
remarks_rows_change = new_remarks[(new_remarks.text.str.contains('[.?!]\s[A-Zc. ]+:'))].index.tolist()
briefings_rows_change = new_briefings[(new_briefings.text.str.contains('[.?!]\s[A-Zc. ]+:'))].index.tolist()
print(len(remarks_rows_change))
print(len(briefings_rows_change))
# Out:
# 86
# 76

# %%
remarks_final = clean_wh.expand_table_mistakes(df=new_remarks, 
                                              rows_of_focus=remarks_rows_change)
briefings_final = clean_wh.expand_table_mistakes(df=new_briefings, 
                                              rows_of_focus=briefings_rows_change)

# %%
remarks_final = pd.read_csv('remarks-whitehouse-ready.csv')
briefings_final = pd.read_csv('briefings-whitehouse-ready.csv')

# %%
unique_remark_ids = remarks_final.doc_id.unique().tolist()
unique_briefing_ids = briefings_final.doc_id.unique().tolist()

new_remark_ids = {unique_remark_ids[idx]:idx for idx in range(len(unique_remark_ids))}

new_briefing_ids = {
    unique_briefing_ids[idx]:max(new_remark_ids.values())+idx+1 for idx in range(len(unique_briefing_ids))
}

remarks_final.doc_id.replace(new_remark_ids, inplace=True)
briefings_final.doc_id.replace(new_briefing_ids, inplace=True)

# %%
remarks_final.speaker = remarks_final.speaker.fillna(method='ffill')

briefings_final.speaker = briefings_final.speaker.fillna(method='ffill')

# %%
final_remarks = clean_wh.condense_table_by_speaker(remarks_final)
final_briefings = clean_wh.condense_table_by_speaker(briefings_final)

# %%
print(f'Remarks table before condensing speakers: {remarks_final.shape}')
print(f'Remarks table after condensing speakers: {final_remarks.shape}')

print(f'\nBriefings table before condensing speakers: {briefings_final.shape}')
print(f'Briefings table after condensing speakers: {final_briefings.shape}')
# Out:
# Remarks table before condensing speakers: (142832, 7)
# Remarks table after condensing speakers: (56132, 6)
#
# Briefings table before condensing speakers: (48409, 7)
# Briefings table after condensing speakers: (30612, 6)

# %%
final_remarks.head(10)
# Out:
#                                                title       date  doc_id  \
# 0        Remarks by Press Secretary Kayleigh McEnany 2021-01-07     0.0
# 1  Remarks by Vice President Pence at the Space F... 2020-12-18     1.0
# 2  Remarks by Vice President Pence at a Safe and ... 2020-12-18     2.0
# 3  Remarks by Vice President Pence at a Life is W... 2020-12-16     3.0
# 4  Remarks by Vice President Pence at a Roundtabl... 2020-12-15     4.0
# 5  Remarks by Vice President Pence at a Roundtabl... 2020-12-15     4.0
# 6  Remarks by Vice President Pence at a Roundtabl... 2020-12-15     4.0
# 7  Remarks by Vice President Pence at a Roundtabl... 2020-12-15     4.0
# 8  Remarks by Vice President Pence at a Roundtabl... 2020-12-15     4.0
# 9  Remarks by Vice President Pence at Roundtable ... 2020-12-10     5.0
#
#               speaker                                               text  \
# 0          MS MCENANY   I am here to deliver this message on behalf o...
# 1  THE VICE PRESIDENT   Well, thank you all for being here today. To ...
# 2  THE VICE PRESIDENT   Well, good morning. And thank you all for bei...
# 3  THE VICE PRESIDENT   Thank you. Thank you all. Thank you all very ...
# 4  THE VICE PRESIDENT   Well, let me — let me let — let me let people...
# 5         DR REDFIELD   Thank you very much, Mr. Vice President. And ...
# 6  THE VICE PRESIDENT   Well, thank you, Dr. Redfield. And before we ...
# 7         DR REDFIELD                                         Yes, sir.
# 8  THE VICE PRESIDENT   — in terms of its ability to truly prevent th...
# 9  THE VICE PRESIDENT   Well, thank you very much, Governor McMaster....
#
#                                                 link
# 0  https://www.whitehouse.gov/briefings-statement...
# 1  https://www.whitehouse.gov/briefings-statement...
# 2  https://www.whitehouse.gov/briefings-statement...
# 3  https://www.whitehouse.gov/briefings-statement...
# 4  https://www.whitehouse.gov/briefings-statement...
# 5  https://www.whitehouse.gov/briefings-statement...
# 6  https://www.whitehouse.gov/briefings-statement...
# 7  https://www.whitehouse.gov/briefings-statement...
# 8  https://www.whitehouse.gov/briefings-statement...
# 9  https://www.whitehouse.gov/briefings-statement...

# %%
final_briefings.head(10)
# Out:
#                                                title       date  doc_id  \
# 0  Press Briefing by Press Secretary Kayleigh McE... 2020-12-16  1930.0
# 1  Press Briefing by Press Secretary Kayleigh McE... 2020-12-16  1930.0
# 2  Press Briefing by Press Secretary Kayleigh McE... 2020-12-16  1930.0
# 3  Press Briefing by Press Secretary Kayleigh McE... 2020-12-16  1930.0
# 4  Press Briefing by Press Secretary Kayleigh McE... 2020-12-16  1930.0
# 5  Press Briefing by Press Secretary Kayleigh McE... 2020-12-16  1930.0
# 6  Press Briefing by Press Secretary Kayleigh McE... 2020-12-16  1930.0
# 7  Press Briefing by Press Secretary Kayleigh McE... 2020-12-16  1930.0
# 8  Press Briefing by Press Secretary Kayleigh McE... 2020-12-16  1930.0
# 9  Press Briefing by Press Secretary Kayleigh McE... 2020-12-16  1930.0
#
#        speaker                                               text  \
# 0   MS MCENANY   Hello, everyone. Good afternoon. Yesterday, t...
# 1  PRESS CORPS   Kayleigh, now that the Electoral College has ...
# 2   MS MCENANY   The President is still involved in ongoing li...
# 3  PRESS CORPS   What was his reaction to Leader McConnell, to...
# 4   MS MCENANY   I haven’t gotten the President’s reaction to ...
# 5  PRESS CORPS   And what is the path forward though for litig...
# 6   MS MCENANY   The campaign would have more specifics for yo...
# 7  PRESS CORPS   Does the President plan to take the vaccine? ...
# 8   MS MCENANY   So the President, currently at this moment, h...
# 9  PRESS CORPS   Wouldn’t him taking the vaccine set an exampl...
#
#                                                 link
# 0  https://www.whitehouse.gov/briefings-statement...
# 1  https://www.whitehouse.gov/briefings-statement...
# 2  https://www.whitehouse.gov/briefings-statement...
# 3  https://www.whitehouse.gov/briefings-statement...
# 4  https://www.whitehouse.gov/briefings-statement...
# 5  https://www.whitehouse.gov/briefings-statement...
# 6  https://www.whitehouse.gov/briefings-statement...
# 7  https://www.whitehouse.gov/briefings-statement...
# 8  https://www.whitehouse.gov/briefings-statement...
# 9  https://www.whitehouse.gov/briefings-statement...

# %%
whitehouse = pd.concat([final_remarks, final_briefings])
whitehouse.reset_index(drop=True, inplace=True)

# %%
whitehouse
# Out:
#                                                    title       date  doc_id  \
# 0            Remarks by Press Secretary Kayleigh McEnany 2021-01-07     0.0
# 1      Remarks by Vice President Pence at the Space F... 2020-12-18     1.0
# 2      Remarks by Vice President Pence at a Safe and ... 2020-12-18     2.0
# 3      Remarks by Vice President Pence at a Life is W... 2020-12-16     3.0
# 4      Remarks by Vice President Pence at a Roundtabl... 2020-12-15     4.0
# 5      Remarks by Vice President Pence at a Roundtabl... 2020-12-15     4.0
# 6      Remarks by Vice President Pence at a Roundtabl... 2020-12-15     4.0
# 7      Remarks by Vice President Pence at a Roundtabl... 2020-12-15     4.0
# 8      Remarks by Vice President Pence at a Roundtabl... 2020-12-15     4.0
# 9      Remarks by Vice President Pence at Roundtable ... 2020-12-10     5.0
# 10     Remarks by Vice President Pence at the 8th Mee... 2020-12-09     6.0
# 11     Remarks by Vice President Pence at the 8th Mee... 2020-12-09     6.0
# 12     Remarks by Vice President Pence at the 8th Mee... 2020-12-09     6.0
# 13     Remarks by Vice President Pence at the Operati... 2020-12-08     7.0
# 14     Remarks by President Trump at the Operation Wa... 2020-12-08     8.0
# 15     Remarks by President Trump at the Operation Wa... 2020-12-08     8.0
# 16     Remarks by President Trump at the Operation Wa... 2020-12-08     8.0
# 17     Remarks by President Trump at the Operation Wa... 2020-12-08     8.0
# 18     Remarks by President Trump at the Operation Wa... 2020-12-08     8.0
# 19     Remarks by President Trump at the Operation Wa... 2020-12-08     8.0
# 20     Remarks by President Trump at the Operation Wa... 2020-12-08     8.0
# 21     Remarks by President Trump at the Operation Wa... 2020-12-08     8.0
# 22     Remarks by President Trump at the Operation Wa... 2020-12-08     8.0
# 23     Remarks by Vice President Pence in a Roundtabl... 2020-12-04     9.0
# 24     Remarks by President Trump at the Presentation... 2020-12-03    10.0
# 25     Remarks by President Trump at the Presentation... 2020-12-03    10.0
# 26     Remarks by President Trump at the Presentation... 2020-12-03    10.0
# 27     Remarks by President Trump at the Presentation... 2020-12-03    10.0
# 28     Remarks by President Trump at the Presentation... 2020-12-03    10.0
# 29     Remarks by President Trump at the Presentation... 2020-12-03    10.0
# ...                                                  ...        ...     ...
# 86714      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86715      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86716      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86717      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86718      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86719      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86720      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86721      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86722      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86723      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86724      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86725      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86726      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86727      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86728      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86729      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86730      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86731      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86732      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86733      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86734      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86735      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86736      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86737      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86738      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86739      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86740      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86741      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86742      Press Briefing by Press Secretary Sean Spicer 2017-02-01  2275.0
# 86743           Statement by Press Secretary Sean Spicer 2017-01-21  2276.0
#
#                          speaker  \
# 0                     MS MCENANY
# 1             THE VICE PRESIDENT
# 2             THE VICE PRESIDENT
# 3             THE VICE PRESIDENT
# 4             THE VICE PRESIDENT
# 5                    DR REDFIELD
# 6             THE VICE PRESIDENT
# 7                    DR REDFIELD
# 8             THE VICE PRESIDENT
# 9             THE VICE PRESIDENT
# 10            THE VICE PRESIDENT
# 11     ADMINISTRATOR BRIDENSTINE
# 12            THE VICE PRESIDENT
# 13            THE VICE PRESIDENT
# 14                 THE PRESIDENT
# 15               AUDIENCE MEMBER
# 16                 THE PRESIDENT
# 17                   PRESS CORPS
# 18                 THE PRESIDENT
# 19                   PRESS CORPS
# 20                 THE PRESIDENT
# 21                   PRESS CORPS
# 22                 THE PRESIDENT
# 23            THE VICE PRESIDENT
# 24                 THE PRESIDENT
# 25                      MR HOLTZ
# 26                 THE PRESIDENT
# 27                      MR HOLTZ
# 28                 THE PRESIDENT
# 29                SENATOR GRAHAM
# ...                          ...
# 86714                  MR SPICER
# 86715                PRESS CORPS
# 86716                  MR SPICER
# 86717                PRESS CORPS
# 86718                  MR SPICER
# 86719                PRESS CORPS
# 86720                  MR SPICER
# 86721                PRESS CORPS
# 86722                  MR SPICER
# 86723                PRESS CORPS
# 86724                  MR SPICER
# 86725                PRESS CORPS
# 86726                  MR SPICER
# 86727                PRESS CORPS
# 86728                  MR SPICER
# 86729                PRESS CORPS
# 86730                  MR SPICER
# 86731                PRESS CORPS
# 86732                  MR SPICER
# 86733                PRESS CORPS
# 86734                  MR SPICER
# 86735                PRESS CORPS
# 86736                  MR SPICER
# 86737                PRESS CORPS
# 86738                  MR SPICER
# 86739                PRESS CORPS
# 86740                  MR SPICER
# 86741                PRESS CORPS
# 86742                  MR SPICER
# 86743                  MR SPICER
#
#                                                     text  \
# 0       I am here to deliver this message on behalf o...
# 1       Well, thank you all for being here today. To ...
# 2       Well, good morning. And thank you all for bei...
# 3       Thank you. Thank you all. Thank you all very ...
# 4       Well, let me — let me let — let me let people...
# 5       Thank you very much, Mr. Vice President. And ...
# 6       Well, thank you, Dr. Redfield. And before we ...
# 7                                             Yes, sir.
# 8       — in terms of its ability to truly prevent th...
# 9       Well, thank you very much, Governor McMaster....
# 10      Well, good afternoon, and thank you all for j...
# 11      Welcome to the Artemis Generation. A lot of y...
# 12      Thank you. Thank you, Jim. It’s now my honor ...
# 13      Well, thank you all very much. Paul, thank yo...
# 14      Thank you very much. Please. . Thank you very...
# 15                            Thank you, Mr. President.
# 16      Thank you very much. Thank you very much, eve...
# 17      Mr. President, it’s clearly a success, this v...
# 18      Yeah, well, CDC puts out their guidelines, an...
# 19      Mr. President, some of these scientific offic...
# 20      Well, they’re Christmas parties, and frankly,...
# 21      The next administration will be the one, ulti...
# 22      Well, we’re going to have to see who the next...
# 23      Well, thank you very much, Dr. Redfield and D...
# 24      Well, thank you very much. Today it’s my priv...
# 25                Oh, very — my son roughed the punter.
# 26          Oh, I — — you weren’t too happy about that.
# 27      Oh, no. I understood why a certain species of...
# 28      So your son has a little of you in him as wel...
# 29            Yeah. Except we don’t play with a helmet.
# ...                                                  ...
# 86714   Thanks, Lars. I think the President has been ...
# 86715   I was wondering about executive orders. You h...
# 86716   Well, I don’t think it’s a binary choice, Dan...
# 86717   The President’s top trade advisor, Peter Nava...
# 86718   I think when it comes to currency valuation, ...
# 86719   Sean, Dan Hausle, 7News of Boston. I’d like t...
# 86720   I was hoping you were going to ask about the ...
# 86721         Well, I would like to ask you about that.
# 86722                           You’ll get a second — —
# 86723   Okay, I’ll get a second. But can you talk abo...
# 86724   Sure. Look, Senator Ayotte is someone who’s r...
# 86725   Her relationship with President Trump was str...
# 86726   That’s right. And I think that that goes and ...
# 86727   As a follow-up — as an unbiased Rhode Island ...
# 86728   I will. I think you know where I come down on...
# 86729   Thanks, Sean. Senators Murkowski and Collins ...
# 86730   Zero. I am 100 percent confident she will be ...
# 86731   In terms of both the two Republican senators ...
# 86732   So first, I would just note, Sarah, that I’ve...
# 86733       But two members of your own party disagree.
# 86734   The vote hasn’t taken place. I think we’ve ha...
# 86735   Thank you for allowing me to be part of today...
# 86736   Thanks, Jeff. I’ve talked about this a couple...
# 86737   Two questions for you. After the primetime an...
# 86738   Yeah, I think on the air time issue, that’s s...
# 86739   The request from Democrats to investigate Fly...
# 86740   Yeah, so General Flynn, like I think probably...
# 86741   Thanks, Sean. General Flynn, when he was up h...
# 86742   I think in area where there’s going to be a s...
# 86743   Good evening. Thank you guys for coming. I kn...
#
#                                                     link
# 0      https://www.whitehouse.gov/briefings-statement...
# 1      https://www.whitehouse.gov/briefings-statement...
# 2      https://www.whitehouse.gov/briefings-statement...
# 3      https://www.whitehouse.gov/briefings-statement...
# 4      https://www.whitehouse.gov/briefings-statement...
# 5      https://www.whitehouse.gov/briefings-statement...
# 6      https://www.whitehouse.gov/briefings-statement...
# 7      https://www.whitehouse.gov/briefings-statement...
# 8      https://www.whitehouse.gov/briefings-statement...
# 9      https://www.whitehouse.gov/briefings-statement...
# 10     https://www.whitehouse.gov/briefings-statement...
# 11     https://www.whitehouse.gov/briefings-statement...
# 12     https://www.whitehouse.gov/briefings-statement...
# 13     https://www.whitehouse.gov/briefings-statement...
# 14     https://www.whitehouse.gov/briefings-statement...
# 15     https://www.whitehouse.gov/briefings-statement...
# 16     https://www.whitehouse.gov/briefings-statement...
# 17     https://www.whitehouse.gov/briefings-statement...
# 18     https://www.whitehouse.gov/briefings-statement...
# 19     https://www.whitehouse.gov/briefings-statement...
# 20     https://www.whitehouse.gov/briefings-statement...
# 21     https://www.whitehouse.gov/briefings-statement...
# 22     https://www.whitehouse.gov/briefings-statement...
# 23     https://www.whitehouse.gov/briefings-statement...
# 24     https://www.whitehouse.gov/briefings-statement...
# 25     https://www.whitehouse.gov/briefings-statement...
# 26     https://www.whitehouse.gov/briefings-statement...
# 27     https://www.whitehouse.gov/briefings-statement...
# 28     https://www.whitehouse.gov/briefings-statement...
# 29     https://www.whitehouse.gov/briefings-statement...
# ...                                                  ...
# 86714  https://www.whitehouse.gov/briefings-statement...
# 86715  https://www.whitehouse.gov/briefings-statement...
# 86716  https://www.whitehouse.gov/briefings-statement...
# 86717  https://www.whitehouse.gov/briefings-statement...
# 86718  https://www.whitehouse.gov/briefings-statement...
# 86719  https://www.whitehouse.gov/briefings-statement...
# 86720  https://www.whitehouse.gov/briefings-statement...
# 86721  https://www.whitehouse.gov/briefings-statement...
# 86722  https://www.whitehouse.gov/briefings-statement...
# 86723  https://www.whitehouse.gov/briefings-statement...
# 86724  https://www.whitehouse.gov/briefings-statement...
# 86725  https://www.whitehouse.gov/briefings-statement...
# 86726  https://www.whitehouse.gov/briefings-statement...
# 86727  https://www.whitehouse.gov/briefings-statement...
# 86728  https://www.whitehouse.gov/briefings-statement...
# 86729  https://www.whitehouse.gov/briefings-statement...
# 86730  https://www.whitehouse.gov/briefings-statement...
# 86731  https://www.whitehouse.gov/briefings-statement...
# 86732  https://www.whitehouse.gov/briefings-statement...
# 86733  https://www.whitehouse.gov/briefings-statement...
# 86734  https://www.whitehouse.gov/briefings-statement...
# 86735  https://www.whitehouse.gov/briefings-statement...
# 86736  https://www.whitehouse.gov/briefings-statement...
# 86737  https://www.whitehouse.gov/briefings-statement...
# 86738  https://www.whitehouse.gov/briefings-statement...
# 86739  https://www.whitehouse.gov/briefings-statement...
# 86740  https://www.whitehouse.gov/briefings-statement...
# 86741  https://www.whitehouse.gov/briefings-statement...
# 86742  https://www.whitehouse.gov/briefings-statement...
# 86743  https://www.whitehouse.gov/briefings-statement...
#
# [86744 rows x 6 columns]

# %%
whitehouse.to_csv('whitehouse-for-preprocessing.csv', index=False)
